# %% [markdown]
# 2.Combined Data

# %% [markdown]
# # 1. Viewing cleaned data using OpenRefine
#
# #21_22
#
# df_2122 = pd.read_csv("eric-sites-21-22-clean.csv")
# df_2122.head()
#
# #22_23
# df_2223 = pd.read_csv("eric-sites-22-23-clean.csv")
# df_2223.head()
#
# #23_24
#
# df_2324 = pd.read_csv("eric-sites-23-24-clean.csv")
# df_2324.head()
#
# #24_25
# df_2425 = pd.read_csv("eric-sites-24-25-clean.csv")
# df_2425.head()

# %%
#2. Combining 4 dataset together
df = pd.concat([df_2122, df_2223, df_2324, df_2425], ignore_index=True)

#3. checking combined data

# number of rows and columns
# (11477, 30)

df.shape

df['year'].value_counts()

df.head()

df.columns

df.sample(10)

#4. Saving combined dataset file

df.to_csv("combined_clean_dataset.csv", index=False)
