# %% [markdown]
# Data Exploration

# %%
# 1. Load the data cleaning tools

import pandas as pd 
import pgeocode

# %%
# 2. Displaying all the columns that are in the dataframe

df = pd.read_csv('data/eric_sites/eric_sites_21_22.csv', encoding='cp1252')

# Display the first 5 rows
df.head()

# %%
# 3.The number of columns in the dataset

#21_22
print("Number of columns in the dataset:", len(df.columns))

#22_23 
print("Number of columns in the dataset:", len(df22_23.columns))

#23_24
print("Number of columns in the dataset:", len(df23_24.columns))

#24_25
print("Number of columns in the dataset:", len(df24_25.columns))

# %%
# 4.Number of rows in datasets - Hospital Sites

print("Number of rows:", len(df))

print("Number of rows:", len(df22_23))

print("Number of rows:", len(df23_24))

print("Number of rows:", len(df24_25))

# %%
# Print out every single column name in a neat vertical list

#21_22
for col in df.columns:
    print(col)
#22_23
for col in df22_23.columns:
    print(col)

#23_24
for col in df23_24.columns:
    print(col)

#24_25
for col in df24_25.columns:
    print(col)
